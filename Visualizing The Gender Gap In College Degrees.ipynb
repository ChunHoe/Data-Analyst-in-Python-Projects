# %% [markdown]
# # Guided Project: Visualizing The Gender Gap In College Degrees

# %%
#Starter Code
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %%
women_degrees.columns
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %% [markdown]
# # Comparing across al degrees

# %%
#Modified Code 2/6
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

stem_cats_order=[1,4,7,10,13,16]
lib_arts_cats_order=[2,5,8,11,14]
other_cats_order=[3,6,9,12,15,18]

all_degree_cats={}
for i in range(0,6):
    all_degree_cats[stem_cats[i]]=stem_cats_order[i]
    all_degree_cats[other_cats[i]]=other_cats_order[i]
    if i < 5:
        all_degree_cats[lib_arts_cats[i]]=lib_arts_cats_order[i]
    
fig = plt.figure(figsize=(18, 3))

for cats,order in all_degree_cats.items():
    ax = fig.add_subplot(6,3,order)
    ax.plot(women_degrees['Year'], women_degrees[cats], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[cats], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(cats)
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if order == 1 or order == 2 or order == 3:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif order == 14 or order == 16 or order == 18:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# # Hiding x-axis labels

# %%
#Modified Code 3/6
#Disable the x-axis labels for all line charts except the bottommost line charts in each column.

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

stem_cats_order=[1,4,7,10,13,16]
lib_arts_cats_order=[2,5,8,11,14]
other_cats_order=[3,6,9,12,15,18]

all_degree_cats={}
for i in range(0,6):
    all_degree_cats[stem_cats[i]]=stem_cats_order[i]
    all_degree_cats[other_cats[i]]=other_cats_order[i]
    if i < 5:
        all_degree_cats[lib_arts_cats[i]]=lib_arts_cats_order[i]
    
fig = plt.figure(figsize=(18, 3))

for cats,order in all_degree_cats.items():
    ax = fig.add_subplot(6,3,order)
    ax.plot(women_degrees['Year'], women_degrees[cats], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[cats], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(cats)
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom="off")
    
    if order == 1 or order == 2 or order == 3:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif order == 14 or order == 16 or order == 18:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom="on")
plt.show()

# %% [markdown]
# # Setting y-axis labels

# %%
#Modified Code 4/6
#Enable for al plots just the y-axis labels at 0 and 100.

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

stem_cats_order=[1,4,7,10,13,16]
lib_arts_cats_order=[2,5,8,11,14]
other_cats_order=[3,6,9,12,15,18]

all_degree_cats={}
for i in range(0,6):
    all_degree_cats[stem_cats[i]]=stem_cats_order[i]
    all_degree_cats[other_cats[i]]=other_cats_order[i]
    if i < 5:
        all_degree_cats[lib_arts_cats[i]]=lib_arts_cats_order[i]
    
fig = plt.figure(figsize=(18, 3))

for cats,order in all_degree_cats.items():
    ax = fig.add_subplot(6,3,order)
    ax.plot(women_degrees['Year'], women_degrees[cats], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[cats], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(cats)
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom="off")
    
    if order == 1 or order == 2 or order == 3:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif order == 14 or order == 16 or order == 18:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom="on")
plt.show()

# %% [markdown]
# # Adding a horizontal line

# %%
#Modified Code 5/6
#Generate a horizontal line

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

stem_cats_order=[1,4,7,10,13,16]
lib_arts_cats_order=[2,5,8,11,14]
other_cats_order=[3,6,9,12,15,18]

all_degree_cats={}
for i in range(0,6):
    all_degree_cats[stem_cats[i]]=stem_cats_order[i]
    all_degree_cats[other_cats[i]]=other_cats_order[i]
    if i < 5:
        all_degree_cats[lib_arts_cats[i]]=lib_arts_cats_order[i]
    
fig = plt.figure(figsize=(18, 3))

for cats,order in all_degree_cats.items():
    ax = fig.add_subplot(6,3,order)
    ax.plot(women_degrees['Year'], women_degrees[cats], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[cats], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(cats)
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom="off")
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    
    if order == 1 or order == 2 or order == 3:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif order == 14 or order == 16 or order == 18:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom="on")
plt.show()

# %% [markdown]
# # Exporting to a file

# %%
#Modified Code 6/6
#Export the figure containing all of the line charts to "gender_degrees.png".

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

stem_cats_order=[1,4,7,10,13,16]
lib_arts_cats_order=[2,5,8,11,14]
other_cats_order=[3,6,9,12,15,18]

all_degree_cats={}
for i in range(0,6):
    all_degree_cats[stem_cats[i]]=stem_cats_order[i]
    all_degree_cats[other_cats[i]]=other_cats_order[i]
    if i < 5:
        all_degree_cats[lib_arts_cats[i]]=lib_arts_cats_order[i]
    
fig = plt.figure(figsize=(18, 18))

for cats,order in all_degree_cats.items():
    ax = fig.add_subplot(6,3,order)
    ax.plot(women_degrees['Year'], women_degrees[cats], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[cats], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(cats)
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom="off")
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    
    if order == 1 or order == 2 or order == 3:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif order == 14 or order == 16 or order == 18:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom="on")

# Export file before calling pyplot.show()        
plt.savefig("gender_degrees.png")
plt.show()
